# %%
#@title Bibliotecas
import pandas as pd
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#@title Leitura base de dados
data = pd.read_csv (r'/content/V2_merge_df.csv') 
dataSet = pd.DataFrame(data)

# %%
#@title Corrigindo o tipo das variáveis categóricas
dataSet[['paciente_Sexo_Feminino', 'paciente_Sexo_Masculino', 'paciente_Raça_Amarelo', 'paciente_Raça_Branco', 'paciente_Raça_Mestiço', 'paciente_Raça_Negro', 'paciente_Procedência_Ambulatorial', 'paciente_Procedência_Internado', 'paciente_Grau de Instrução_1ª a 4ª série', 'paciente_Grau de Instrução_2º grau', 'paciente_Grau de Instrução_5ª a 8ª série', 'paciente_Grau de Instrução_Mestrado ou Doutorado', 'paciente_Grau de Instrução_Não alfabetizado', 'paciente_Grau de Instrução_Não sabe/Sem declaração', 'paciente_Grau de Instrução_Superior', 'paciente_HAS_Não', 'paciente_HAS_Sim', 'paciente_Diabetes_Não', 'paciente_Diabetes_Sim', 'paciente_Tratamento Diabetes_Dieta', 'paciente_Tratamento Diabetes_Hipoglicemiante Oral', 'paciente_Tratamento Diabetes_Insulino Dependente', 'paciente_Tratamento Diabetes_Sem Tratamento', 'paciente_Dislipidemia_Não', 'paciente_Dislipidemia_Sim', 'paciente_Tratamento Dislipidemia_Dieta', 'paciente_Tratamento Dislipidemia_Estatina', 'paciente_Tratamento Dislipidemia_Fibrato', 'paciente_Tratamento Dislipidemia_Fibrato e Estatina', 'paciente_Tratamento Dislipidemia_Sem Tratamento', 'paciente_Tabagista_Não', 'paciente_Tabagista_Sim', 'paciente_Cigarros (dia) - Tabagista_gt 40', 'paciente_Cigarros (dia) - Tabagista_de 10 a 20', 'paciente_Cigarros (dia) - Tabagista_de 20 a 40', 'paciente_Cigarros (dia) - Tabagista_de 5 a 10', 'paciente_Tempo_lt 5 anos', 'paciente_Tempo_gt 20 anos', 'paciente_Tempo_de 10 a 15 anos', 'paciente_Tempo_de 15 a 20 anos', 'paciente_Tempo_de 5 a 10 anos', 'paciente_Ex-Tabagista_Não', 'paciente_Ex-Tabagista_Sim', 'paciente_Cigarros (dia) - Ex-Tabagista_gt 40', 'paciente_Cigarros (dia) - Ex-Tabagista_de 10 a 20', 'paciente_Cigarros (dia) - Ex-Tabagista_de 20 a 40', 'paciente_Cigarros (dia) - Ex-Tabagista_de 5 a 10', 'paciente_Tempo de Interrupção_Parou lt 10 anos', 'paciente_Tempo de Interrupção_Parou gt 10 anos', 'paciente_IAM Prévio_Não', 'paciente_IAM Prévio_Sim', 'paciente_Síndrome Metabólica_Não', 'paciente_Síndrome Metabólica_Sim', 'paciente_Antecedentes Familiares_Não', 'paciente_Antecedentes Familiares_Sim', 'paciente_Tipo Antecedentes Familiares_Não Precoce', 'paciente_Tipo Antecedentes Familiares_Precoce', 'paciente_IRC_Não', 'paciente_IRC_Sim', 'paciente_Tipo IRC_Dialítica', 'paciente_Tipo IRC_Não Dialítica', 'paciente_AVC prévio_Não', 'paciente_AVC prévio_Sim', 'paciente_Doença Vascular Periférica_Não', 'paciente_Doença Vascular Periférica_Sim', 'paciente_Tipo Doença Vascular Periférica_Não Operada', 'paciente_Tipo Doença Vascular Periférica_Operada / Intervenção prévia', 'paciente_História de Trombose Venosa Profunda_Não', 'paciente_História de Trombose Venosa Profunda_Sim', 'paciente_DPOC_Não', 'paciente_DPOC_Sim', 'paciente_Alergia ao iodo_Não', 'paciente_Alergia ao iodo_Sim', 'paciente_DAC conhecida_Não', 'paciente_DAC conhecida_Sim', 'paciente_Cate Prévio_Não', 'paciente_Cate Prévio_Sim', 'paciente_Cirurgia de Revascularização Prévia_Não', 'paciente_Cirurgia de Revascularização Prévia_Sim', 'paciente_Intervenção Percutânea Prévia_Não', 'paciente_Intervenção Percutânea Prévia_Sim', 'procedimento_Anestesia - Intervenção_Geral Inalatória_sum', 'procedimento_Anestesia - Intervenção_Geral Sedação_sum', 'procedimento_Anestesia - Intervenção_Local_sum', 'procedimento_Droga - Intervenção_Fentanil_sum', 'procedimento_Droga - Intervenção_Midazolan_sum', 'procedimento_Droga - Intervenção_Propafenona_sum', 'procedimento_Droga - Intervenção_Thionembutal_sum', 'procedimento_Droga - Intervenção_Xilocaína 2%_sum', 'procedimento_Técnica - Intervenção_Convencional_sum', 'procedimento_Técnica - Intervenção_kissing-balloon_sum', 'procedimento_Introdutor - Intervenção_10F_sum', 'procedimento_Introdutor - Intervenção_11F_sum', 'procedimento_Introdutor - Intervenção_5F_sum', 'procedimento_Introdutor - Intervenção_6F_sum', 'procedimento_Introdutor - Intervenção_7F_sum', 'procedimento_Introdutor - Intervenção_8F_sum', 'procedimento_Introdutor - Intervenção_9F_sum', 'procedimento_Via de acesso - Intervenção_Braquial Dissecção_sum', 'procedimento_Via de acesso - Intervenção_Braquial Punção_sum', 'procedimento_Via de acesso - Intervenção_Femoral_sum', 'procedimento_Via de acesso - Intervenção_Radial_sum', 'procedimento_Lado Via de Acesso - Intervenção_Direito_sum', 'procedimento_Lado Via de Acesso - Intervenção_Direito e Esquerdo_sum', 'procedimento_Lado Via de Acesso - Intervenção_Esquerdo_sum', 'procedimento_Tipo Contraste - Intervenção_Iônico de alta osmolaridade_sum', 'procedimento_Tipo Contraste - Intervenção_Iônico de baixa osmolaridade_sum', 'procedimento_Tipo Contraste - Intervenção_Não iônico de baixa osmolaridade_sum', 'procedimento_Tipo Contraste - Intervenção_Não iônico isoosmolar_sum', 'procedimento_Nome Comercial - Intervenção_CONRAY 60_sum', 'procedimento_Nome Comercial - Intervenção_HENETIX 300_sum', 'procedimento_Nome Comercial - Intervenção_HENETIX 350_sum', 'procedimento_Nome Comercial - Intervenção_HEXABRIX 320_sum', 'procedimento_Nome Comercial - Intervenção_IOPAMIRON 300_sum', 'procedimento_Nome Comercial - Intervenção_IOPAMIRON 370_sum', 'procedimento_Nome Comercial - Intervenção_OMNIPAQUE 300_sum', 'procedimento_Nome Comercial - Intervenção_OPTIRAY 240_sum', 'procedimento_Nome Comercial - Intervenção_OPTIRAY 320_sum', 'procedimento_Nome Comercial - Intervenção_OPTIRAY 350_sum', 'procedimento_Nome Comercial - Intervenção_PIELOGRAF 76_sum', 'procedimento_Nome Comercial - Intervenção_TELEBRIX 35_sum', 'procedimento_Nome Comercial - Intervenção_ULTRAVIST 300_sum', 'procedimento_Nome Comercial - Intervenção_VISIPAQUE 270_sum', 'procedimento_Nome Comercial - Intervenção_VISIPAQUE 320_sum', 'procedimento_Tipo de Intervenção_Ad-hoc_sum', 'procedimento_Tipo de Intervenção_Eletiva_sum', 'procedimento_Tipo de Intervenção_Facilitada_sum', 'procedimento_Tipo de Intervenção_Primária_sum', 'procedimento_Tipo de Intervenção_Resgate_sum', 'procedimento_Tipo de Intervenção_Urgência_sum', 'procedimento_Trombolítico Prévio - Primária_Nenhum_sum', 'procedimento_Trombolítico Prévio - Primária_SK_sum', 'procedimento_Trombolítico Prévio - Primária_TNK_sum', 'procedimento_Trombolítico Prévio - Primária_TPA_sum', 'procedimento_Trombolítico Prévio - Primária_rPA_sum', 'procedimento_Trombolítico Prévio - Resgate_Nenhum_sum', 'procedimento_Trombolítico Prévio - Resgate_SK_sum', 'procedimento_Trombolítico Prévio - Resgate_TNK_sum', 'procedimento_Trombolítico Prévio - Resgate_TPA_sum', 'procedimento_Trombolítico Prévio - Resgate_rPA_sum', 'procedimento_Trombolítico Prévio - Eletiva_Nenhum_sum', 'procedimento_Trombolítico Prévio - Eletiva_SK_sum', 'procedimento_Trombolítico Prévio - Eletiva_TNK_sum', 'procedimento_Trombolítico Prévio - Eletiva_TPA_sum', 'procedimento_Trombolítico Prévio - Eletiva_rPA_sum', 'procedimento_Trombolítico Prévio - Ad-hoc_Nenhum_sum', 'procedimento_Trombolítico Prévio - Ad-hoc_SK_sum', 'procedimento_Trombolítico Prévio - Ad-hoc_TNK_sum', 'procedimento_Trombolítico Prévio - Ad-hoc_TPA_sum', 'procedimento_Trombolítico Prévio - Ad-hoc_rPA_sum', 'procedimento_TCA_3.0_sum', 'procedimento_TCA_30.0_sum', 'procedimento_TCA_167.0_sum', 'procedimento_TCA_180.0_sum', 'procedimento_TCA_195.0_sum', 'procedimento_TCA_250.0_sum', 'procedimento_TCA_256.0_sum', 'procedimento_TCA_262.0_sum', 'procedimento_TCA_277.0_sum', 'procedimento_TCA_280.0_sum', 'procedimento_TCA_291.0_sum', 'procedimento_TCA_295.0_sum', 'procedimento_TCA_311.0_sum', 'procedimento_TCA_348.0_sum', 'procedimento_TCA_380.0_sum', 'procedimento_TCA_418.0_sum', 'procedimento_TCA_475.0_sum', 'procedimento_AAS_Não_sum', 'procedimento_AAS_Sim_sum', 'procedimento_Ticlopidina_Não_sum', 'procedimento_Ticlopidina_Sim_sum', 'procedimento_Clopidogrel_Não_sum', 'procedimento_Clopidogrel_Sim_sum', 'procedimento_HNF_Não_sum', 'procedimento_HNF_Sim_sum', 'procedimento_HBPM_Não_sum', 'procedimento_HBPM_Sim_sum', 'procedimento_Abciximab_Não_sum', 'procedimento_Abciximab_Sim_sum', 'procedimento_Tirofiban_Não_sum', 'procedimento_Tirofiban_Sim_sum', 'procedimento_Eptifibatide_Não_sum', 'procedimento_Eptifibatide_Sim_sum', 'procedimento_Adenosina_Não_sum', 'procedimento_Adenosina_Sim_sum', 'procedimento_Ultrasom Intracoronário_Não_sum', 'procedimento_Ultrasom Intracoronário_Sim_sum', 'procedimento_Angiografia Quantitativa_Não_sum', 'procedimento_Angiografia Quantitativa_Sim_sum', 'procedimento_Inibidor de glicoproteína_Agrastat_sum', 'procedimento_Inibidor de glicoproteína_Nenhum_sum', 'procedimento_Inibidor de glicoproteína_Reo-Pro_sum', 'procedimento_Clopidogrel.1_lt 6h_sum', 'procedimento_Clopidogrel.1_gt 6h_sum', 'procedimento_Clopidogrel.1_Não_sum', 'complicacao_Quando_Até 1 semana_sum', 'complicacao_Quando_Até 24 horas_sum', 'complicacao_Quando_Intra-exame até a alta_sum', 'complicacao_Quando_Recuperação_sum', 'complicacao_Quando_Sala de exame_sum', 'complicacao_Destino Alta_Domiciliar_sum', 'complicacao_Destino Alta_Enfermaria_sum', 'complicacao_Destino Alta_Hospital Origem_sum', 'complicacao_Óbito_Não_sum', 'complicacao_Óbito_Sim_sum', 'complicacao_Tipo Complicação_Alérgica_sum', 'complicacao_Tipo Complicação_Arritmia_sum', 'complicacao_Tipo Complicação_Congestiva_sum', 'complicacao_Tipo Complicação_Embólica_sum', 'complicacao_Tipo Complicação_Hematoma_sum', 'complicacao_Tipo Complicação_Isquêmica_sum', 'complicacao_Tipo Complicação_Neurológica_sum', 'complicacao_Tipo Complicação_R. Contraste_sum', 'complicacao_Tipo Complicação_Vagal_sum', 'complicacao_Tipo Complicação_Vascular_sum', 'complicacao_Grau - Complicação_Grave_sum', 'complicacao_Grau - Complicação_Leve_sum', 'complicacao_Grau - Complicação_Moderado_sum', 'complicacao_Conduta_Orientação Telefônica_sum', 'complicacao_Conduta_Retorno para avaliação Médica_sum', 'balao_N. Injeções - Adenosina - Balão_sum', 'balao_Total Injetado (mg) - Adenosina - Balão_sum', 'balao_N. Injeções - Papaverina - Balão_sum', 'balao_Total Injetado (mg) - Papaverina - Balão_sum', 'balao_N. Injeções - Nitroglicerina - Balão_sum', 'balao_Total Injetado (mg) - Nitroglicerina - Balão_sum', 'balao_N. Injeções - Monocordil - Balão_sum', 'balao_Total Injetado (mg) - Monocordil - Balão_sum', 'balao_N. Injeções - Nitroprussiato - Balão_sum', 'balao_Total Injetado (mg) - Nitroprussiato - Balão_sum', 'balao_N. Injeções - Adrenalina - Balão_sum', 'balao_Total Injetado (mg) - Adrenalina - Balão_sum', 'balao_Device Adjunto - Balão_Braquiterapia_sum', 'balao_Device Adjunto - Balão_Exciser_sum', 'balao_Resultado Angiográfico - Balão_I1 - Não ultrapassou a lesão_sum', 'balao_Resultado Angiográfico - Balão_I2 - Ultrapassou e não dilatou_sum', 'balao_Resultado Angiográfico - Balão_I3 - Oclusão Aguda_sum', 'balao_Resultado Angiográfico - Balão_I4 - Dissecção_sum', 'balao_Resultado Angiográfico - Balão_S - Sucesso_sum', 'balao_Tipo - Dissecção - Balão_A_sum', 'balao_Tipo - Dissecção - Balão_B_sum', 'balao_Tipo - Dissecção - Balão_C_sum', 'balao_Tipo - Dissecção - Balão_D_sum', 'balao_Tipo - Dissecção - Balão_E_sum', 'balao_Tipo - Dissecção - Balão_F_sum', 'balao_Classificação da Lesão (ACC/AHA) - Balão_A_sum', 'balao_Classificação da Lesão (ACC/AHA) - Balão_B1_sum', 'balao_Classificação da Lesão (ACC/AHA) - Balão_B2_sum', 'balao_Classificação da Lesão (ACC/AHA) - Balão_C_sum', 'balao
coronário - Stent_MamáriaMg_sum', 'stent_Vaso coronário - Stent_Mg1_sum', 'stent_Vaso coronário - Stent_Mg2_sum', 'stent_Vaso coronário - Stent_Mg3_sum', 'stent_Vaso coronário - Stent_Mg4_sum', 'stent_Vaso coronário - Stent_MgD_sum', 'stent_Vaso coronário - Stent_PVSCD_sum', 'stent_Vaso coronário - Stent_PVSDA_sum', 'stent_Vaso coronário - Stent_PVSDPD_sum', 'stent_Vaso coronário - Stent_PVSDPE_sum', 'stent_Vaso coronário - Stent_PVSDg1_sum', 'stent_Vaso coronário - Stent_PVSDg2_sum', 'stent_Vaso coronário - Stent_PVSMg1_sum', 'stent_Vaso coronário - Stent_PVSMg2_sum', 'stent_Vaso coronário - Stent_PVSRI_sum', 'stent_Vaso coronário - Stent_PVSVPD_sum', 'stent_Vaso coronário - Stent_PVSVPE_sum', 'stent_Vaso coronário - Stent_RadialCD_sum', 'stent_Vaso coronário - Stent_RadialDg_sum', 'stent_Vaso coronário - Stent_RadialMg_sum', 'stent_Vaso coronário - Stent_TCE_sum', 'stent_Vaso coronário - Stent_VPD_sum', 'stent_Vaso coronário - Stent_VPE_sum', 'stent_Stent_BIO MATRIX_sum', 'stent_Stent_BIONERT_sum', 'stent_Stent_BIOTRONIK_sum', 'stent_Stent_CARBOSTENT_sum', 'stent_Stent_CONOR_sum', 'stent_Stent_COROFLEX BLUE_sum', 'stent_Stent_CYPHER_sum', 'stent_Stent_DIRECT STENT_sum', 'stent_Stent_DRIVER_sum', 'stent_Stent_ELIXIR_sum', 'stent_Stent_ENDEAVOR_sum', 'stent_Stent_ENDEAVOR RESOLUTE_sum', 'stent_Stent_EXPRESS_sum', 'stent_Stent_GENIUS_sum', 'stent_Stent_INSPIRON_sum', 'stent_Stent_INTEGRITY_sum', 'stent_Stent_KANAME_sum', 'stent_Stent_LEKTON_sum', 'stent_Stent_LEKTON MOTION_sum', 'stent_Stent_LEVENTON_sum', 'stent_Stent_LIBERTÉ_sum', 'stent_Stent_MATRIX_sum', 'stent_Stent_MGUARD_sum', 'stent_Stent_MICRO DRIVER_sum', 'stent_Stent_MICROPORT_sum', 'stent_Stent_MINI DRIVER_sum', 'stent_Stent_MULTILINK_sum', 'stent_Stent_NILE CROCO_sum', 'stent_Stent_NOBORI_sum', 'stent_Stent_OMEGA_sum', 'stent_Stent_PRESILLION_sum', 'stent_Stent_PRO-KINETIC_sum', 'stent_Stent_PROMUS_sum', 'stent_Stent_PROMUS ELEMENT_sum', 'stent_Stent_R-STENT_sum', 'stent_Stent_REBEL_sum', 'stent_Stent_RESOLUTE_sum', 'stent_Stent_RESOLUTE INTEGRITY_sum', 'stent_Stent_SINERGY_sum', 'stent_Stent_SIRIUS_sum', 'stent_Stent_SONIC_sum', 'stent_Stent_SUPRALIMUS_sum', 'stent_Stent_TAXUS_sum', 'stent_Stent_TENSUN_sum', 'stent_Stent_ULTIMASTER_sum', 'stent_Stent_ULTRA_sum', 'stent_Stent_V-FLEX_sum', 'stent_Stent_VISION_sum', 'stent_Stent_WIKTOR_sum', 'stent_Stent_XIENCE PRIME_sum', 'stent_Stent_XIENCE V_sum', 'stent_Stent_XIENCE XPEDITION_sum', 'stent_Stent_XT BARD_sum', 'stent_Stent_ZETA_sum', 'stent_Estratégia_Pré e Pós dilatação_sum', 'stent_Estratégia_Pré-dilatação_sum', 'stent_Estratégia_Pós-dilatação_sum', 'stent_Estratégia_Stent Direto_sum', 'stent_Resultado Angiográfico - Stent_I1 - Não ultrapassou a lesão_sum', 'stent_Resultado Angiográfico - Stent_I2 - Ultrapassou e não dilatou_sum', 'stent_Resultado Angiográfico - Stent_I3 - Oclusão Aguda_sum', 'stent_Resultado Angiográfico - Stent_I4 - Dissecção_sum', 'stent_Resultado Angiográfico - Stent_S - Sucesso_sum', 'stent_Tipo - Dissecção - Stent_A_sum', 'stent_Tipo - Dissecção - Stent_B_sum', 'stent_Tipo - Dissecção - Stent_C_sum', 'stent_Tipo - Dissecção - Stent_D_sum', 'stent_Tipo - Dissecção - Stent_E_sum', 'stent_Tipo - Dissecção - Stent_F_sum', 'stent_Localização da Dissecção_Pré Stent_sum', 'stent_Localização da Dissecção_Pré e Pós Stent_sum', 'stent_Localização da Dissecção_Pós Stent_sum', 'stent_Classificação da Lesão (ACC/AHA) - Stent_A_sum', 'stent_Classificação da Lesão (ACC/AHA) - Stent_B1_sum', 'stent_Classificação da Lesão (ACC/AHA) - Stent_B2_sum', 'stent_Classificação da Lesão (ACC/AHA) - Stent_C_sum', 'stent_Kissing wire - Stent_Não_sum', 'stent_Kissing wire - Stent_Sim_sum', 'stent_Kissing balloon - Stent_Não_sum', 'stent_Kissing balloon - Stent_Sim_sum', 'stent_Sobreposição_Não_sum', 'stent_Sobreposição_Sim_sum', 'stent_Distúrbio de Fluxo - Stent_Não_sum', 'stent_Distúrbio de Fluxo - Stent_Sim_sum', 'stent_Tipo do Distúrbio de Fluxo - Stent_No-reflow_sum', 'stent_Tipo do Distúrbio de Fluxo - Stent_Slow flow_sum', 'stent_Tipo No-Reflow_Inalterado após as medicações descritas_sum', 'stent_Tipo No-Reflow_Melhora completa_sum', 'stent_Tipo No-Reflow_Melhora parcial_sum', 'stent_Técnica de bifurcação_Crushing_sum', 'stent_Técnica de bifurcação_Cullote_sum', 'stent_Técnica de bifurcação_Mini Crushing_sum', 'stent_Técnica de bifurcação_SKS_sum', 'stent_Técnica de bifurcação_T Provisional_sum', 'stent_Técnica de bifurcação_T Stent_sum', 'stent_Técnica de bifurcação_V Stent_sum', 'stent_Stent Dedicado_Não_sum', 'stent_Stent Dedicado_Sim_sum', 'stent_Adenosina - Stent_Não_sum', 'stent_Adenosina - Stent_Sim_sum', 'stent_Papaverina - Stent_Não_sum', 'stent_Papaverina - Stent_Sim_sum', 'stent_Nitroglicerina - Stent_Não_sum', 'stent_Nitroglicerina - Stent_Sim_sum', 'stent_Monocordil - Stent_Não_sum', 'stent_Monocordil - Stent_Sim_sum', 'stent_Nitroprussiato - Stent_Não_sum', 'stent_Adrenalina - Stent_Não_sum', 'stent_Adrenalina - Stent_Sim_sum', 'vaso_Anatomia - Intervenção_Ateromatose moderada_sum', 
gia de Revascularização Prévia_Sim', 'paciente_Intervenção Percutânea Prévia_Não', 'paciente_Intervenção Percutânea Prévia_Sim', 'procedimento_Anestesia - Intervenção_Geral Inalatória_sum', 'procedimento_Anestesia - Intervenção_Geral Sedação_sum', 'procedimento_Anestesia - Intervenção_Local_sum', 'procedimento_Droga - Intervenção_Fentanil_sum', 'procedimento_Droga - Intervenção_Midazolan_sum', 'procedimento_Droga - Intervenção_Propafenona_sum', 'procedimento_Droga - Intervenção_Thionembutal_sum', 'procedimento_Droga - Intervenção_Xilocaína 2%_sum', 'procedimento_Técnica - Intervenção_Convencional_sum', 'procedimento_Técnica - Intervenção_kissing-balloon_sum', 'procedimento_Introdutor - Intervenção_10F_sum', 'procedimento_Introdutor - Intervenção_11F_sum', 'procedimento_Introdutor - Intervenção_5F_sum', 'procedimento_Introdutor - Intervenção_6F_sum', 'procedimento_Introdutor - Intervenção_7F_sum', 'procedimento_Introdutor - Intervenção_8F_sum', 'procedimento_Introdutor - Intervenção_9F_sum', 'procedimento_Via de acesso - Intervenção_Braquial Dissecção_sum', 'procedimento_Via de acesso - Intervenção_Braquial Punção_sum', 'procedimento_Via de acesso - Intervenção_Femoral_sum', 'procedimento_Via de acesso - Intervenção_Radial_sum', 'procedimento_Lado Via de Acesso - Intervenção_Direito_sum', 'procedimento_Lado Via de Acesso - Intervenção_Direito e Esquerdo_sum', 'procedimento_Lado Via de Acesso - Intervenção_Esquerdo_sum', 'procedimento_Tipo Contraste - Intervenção_Iônico de alta osmolaridade_sum', 'procedimento_Tipo Contraste - Intervenção_Iônico de baixa osmolaridade_sum', 'procedimento_Tipo Contraste - Intervenção_Não iônico de baixa osmolaridade_sum', 'procedimento_Tipo Contraste - Intervenção_Não iônico isoosmolar_sum', 'procedimento_Nome Comercial - Intervenção_CONRAY 60_sum', 'procedimento_Nome Comercial - Intervenção_HENETIX 300_sum', 'procedimento_Nome Comercial - Intervenção_HENETIX 350_sum', 'procedimento_Nome Comercial - Intervenção_HEXABRIX 320_sum', 'procedimento_Nome Comercial - Intervenção_IOPAMIRON 300_sum', 'procedimento_Nome Comercial - Intervenção_IOPAMIRON 370_sum', 'procedimento_Nome Comercial - Intervenção_OMNIPAQUE 300_sum', 'procedimento_Nome Comercial - Intervenção_OPTIRAY 240_sum', 'procedimento_Nome Comercial - Intervenção_OPTIRAY 320_sum', 'procedimento_Nome Comercial - Intervenção_OPTIRAY 350_sum', 'procedimento_Nome Comercial - Intervenção_PIELOGRAF 76_sum', 'procedimento_Nome Comercial - Intervenção_TELEBRIX 35_sum', 'procedimento_Nome Comercial - Intervenção_ULTRAVIST 300_sum', 'procedimento_Nome Comercial - Intervenção_VISIPAQUE 270_sum', 'procedimento_Nome Comercial - Intervenção_VISIPAQUE 320_sum', 'procedimento_Tipo de Intervenção_Ad-hoc_sum', 'procedimento_Tipo de Intervenção_Eletiva_sum', 'procedimento_Tipo de Intervenção_Facilitada_sum', 'procedimento_Tipo de Intervenção_Primária_sum', 'procedimento_Tipo de Intervenção_Resgate_sum', 'procedimento_Tipo de Intervenção_Urgência_sum', 'procedimento_Trombolítico Prévio - Primária_Nenhum_sum', 'procedimento_Trombolítico Prévio - Primária_SK_sum', 'procedimento_Trombolítico Prévio - Primária_TNK_sum', 'procedimento_Trombolítico Prévio - Primária_TPA_sum', 'procedimento_Trombolítico Prévio - Primária_rPA_sum', 'procedimento_Trombolítico Prévio - Resgate_Nenhum_sum', 'procedimento_Trombolítico Prévio - Resgate_SK_sum', 'procedimento_Trombolítico Prévio - Resgate_TNK_sum', 'procedimento_Trombolítico Prévio - Resgate_TPA_sum', 'procedimento_Trombolítico Prévio - Resgate_rPA_sum', 'procedimento_Trombolítico Prévio - Eletiva_Nenhum_sum', 'procedimento_Trombolítico Prévio - Eletiva_SK_sum', 'procedimento_Trombolítico Prévio - Eletiva_TNK_sum', 'procedimento_Trombolítico Prévio - Eletiva_TPA_sum', 'procedimento_Trombolítico Prévio - Eletiva_rPA_sum', 'procedimento_Trombolítico Prévio - Ad-hoc_Nenhum_sum', 'procedimento_Trombolítico Prévio - Ad-hoc_SK_sum', 'procedimento_Trombolítico Prévio - Ad-hoc_TNK_sum', 'procedimento_Trombolítico Prévio - Ad-hoc_TPA_sum', 'procedimento_Trombolítico Prévio - Ad-hoc_rPA_sum', 'procedimento_TCA_3.0_sum', 'procedimento_TCA_30.0_sum', 'procedimento_TCA_167.0_sum', 'procedimento_TCA_180.0_sum', 'procedimento_TCA_195.0_sum', 'procedimento_TCA_250.0_sum', 'procedimento_TCA_256.0_sum', 'procedimento_TCA_262.0_sum', 'procedimento_TCA_277.0_sum', 'procedimento_TCA_280.0_sum', 'procedimento_TCA_291.0_sum', 'procedimento_TCA_295.0_sum', 'procedimento_TCA_311.0_sum', 'procedimento_TCA_348.0_sum', 'procedimento_TCA_380.0_sum', 'procedimento_TCA_418.0_sum', 'procedimento_TCA_475.0_sum', 'procedimento_AAS_Não_sum', 'procedimento_AAS_Sim_sum', 'procedimento_Ticlopidina_Não_sum', 'procedimento_Ticlopidina_Sim_sum', 'procedimento_Clopidogrel_Não_sum', 'procedimento_Clopidogrel_Sim_sum', 'procedimento_HNF_Não_sum', 'procedimento_HNF_Sim_sum', 'procedimento_HBPM_Não_sum', 'procedimento_HBPM_Sim_sum', 'procedimento_Abciximab_Não_sum', 'procedimento_Abciximab_Sim_sum', 'procedimento_Tirofiban_Não_sum', 'procedimento_Tirofiban_Sim_sum', 'procedimento_Eptifibatide_Não_sum', 'procedimento_Eptifibatide_Sim_sum', 'procedimento_Adenosina_Não_sum', 'procedimento_Adenosina_Sim_sum', 'procedimento_Ultrasom Intracoronário_Não_sum', 'procedimento_Ultrasom Intracoronário_Sim_sum', 'procedimento_Angiografia Quantitativa_Não_sum', 'procedimento_Angiografia Quantitativa_Sim_sum', 'procedimento_Inibidor de glicoproteína_Agrastat_sum', 'procedimento_Inibidor de glicoproteína_Nenhum_sum', 'procedimento_Inibidor de glicoproteína_Reo-Pro_sum', 'procedimento_Clopidogrel.1_lt 6h_sum', 'procedimento_Clopidogrel.1_gt 6h_sum', 'procedimento_Clopidogrel.1_Não_sum', 'complicacao_Quando_Até 1 semana_sum', 'complicacao_Quando_Até 24 horas_sum', 'complicacao_Quando_Intra-exame até a alta_sum', 'complicacao_Quando_Recuperação_sum', 'complicacao_Quando_Sala de exame_sum', 'complicacao_Destino Alta_Domiciliar_sum', 'complicacao_Destino Alta_Enfermaria_sum', 'complicacao_Destino Alta_Hospital Origem_sum', 'complicacao_Óbito_Não_sum', 'complicacao_Óbito_Sim_sum', 'complicacao_Tipo Complicação_Alérgica_sum', 'complicacao_Tipo Complicação_Arritmia_sum', 'complicacao_Tipo Complicação_Congestiva_sum', 'complicacao_Tipo Complicação_Embólica_sum', 'complicacao_Tipo Complicação_Hematoma_sum', 'complicacao_Tipo Complicação_Isquêmica_sum', 'complicacao_Tipo Complicação_Neurológica_sum', 'complicacao_Tipo Complicação_R. Contraste_sum', 'complicacao_Tipo Complicação_Vagal_sum', 'complicacao_Tipo Complicação_Vascular_sum', 'complicacao_Grau - Complicação_Grave_sum', 'complicacao_Grau - Complicação_Leve_sum', 'complicacao_Grau - Complicação_Moderado_sum', 'complicacao_Conduta_Orientação Telefônica_sum', 'complicacao_Conduta_Retorno para avaliação Médica_sum', 'balao_N. Injeções - Adenosina - Balão_sum', 'balao_Total Injetado (mg) - Adenosina - Balão_sum', 'balao_N. Injeções - Papaverina - Balão_sum', 'balao_Total Injetado (mg) - Papaverina - Balão_sum', 'balao_N. Injeções - Nitroglicerina - Balão_sum', 'balao_Total Injetado (mg) - Nitroglicerina - Balão_sum', 'balao_N. Injeções - Monocordil - Balão_sum', 'balao_Total Injetado (mg) - Monocordil - Balão_sum', 'balao_N. Injeções - Nitroprussiato - Balão_sum', 'balao_Total Injetado (mg) - Nitroprussiato - Balão_sum', 'balao_N. Injeções - Adrenalina - Balão_sum', 'balao_Total Injetado (mg) - Adrenalina - Balão_sum', 'balao_Device Adjunto - Balão_Braquiterapia_sum', 'balao_Device Adjunto - Balão_Exciser_sum', 'balao_Resultado Angiográfico - Balão_I1 - Não ultrapassou a lesão_sum', 'balao_Resultado Angiográfico - Balão_I2 - Ultrapassou e não dilatou_sum', 'balao_Resultado Angiográfico - Balão_I3 - Oclusão Aguda_sum', 'balao_Resultado Angiográfico - Balão_I4 - Dissecção_sum', 'balao_Resultado Angiográfico - Balão_S - Sucesso_sum', 'balao_Tipo - Dissecção - Balão_A_sum', 'balao_Tipo - Dissecção - Balão_B_sum', 'balao_Tipo - Dissecção - Balão_C_sum', 'balao_Tipo - Dissecção - Balão_D_sum', 'balao_Tipo - Dissecção - Balão_E_sum', 'balao_Tipo - Dissecção - Balão_F_sum', 'balao_Classificação da Lesão (ACC/AHA) - Balão_A_sum', 'balao_Classificação da Lesão (ACC/AHA) - Balão_B1_sum', 'balao_Classificação da Lesão (ACC/AHA) - Balão_B2_sum', 'balao_Classificação da Lesão (ACC/AHA) - Balão_C_sum', 'balao_Distúrbio de Fluxo - Balão_Não_sum', 'balao_Distúrbio de Fluxo - Balão_Sim_sum', 'balao_Tipo do Distúrbio de Fluxo - Balão_No-reflow_sum', 'balao_Tipo do Distúrbio de Fluxo - Balão_Slow flow_sum', 'balao_Tipo No-Reflow_Inalterado após as medicações descritas_sum', 'balao_Tipo No-Reflow_Melhora completa_sum', 'balao_Tipo No-Reflow_Melhora parcial_sum', 'balao_Vaso coron
 'stent_Vaso coronário - Stent_PVSDPE_sum', 'stent_Vaso coronário - Stent_PVSDg1_sum', 'stent_Vaso coronário - Stent_PVSDg2_sum', 'stent_Vaso coronário - Stent_PVSMg1_sum', 'stent_Vaso coronário - Stent_PVSMg2_sum', 'stent_Vaso coronário - Stent_PVSRI_sum', 'stent_Vaso coronário - Stent_PVSVPD_sum', 'stent_Vaso coronário - Stent_PVSVPE_sum', 'stent_Vaso coronário - Stent_RadialCD_sum', 'stent_Vaso coronário - Stent_RadialDg_sum', 'stent_Vaso coronário - Stent_RadialMg_sum', 'stent_Vaso coronário - Stent_TCE_sum', 'stent_Vaso coronário - Stent_VPD_sum', 'stent_Vaso coronário - Stent_VPE_sum', 'stent_Stent_BIO MATRIX_sum', 'stent_Stent_BIONERT_sum', 'stent_Stent_BIOTRONIK_sum', 'stent_Stent_CARBOSTENT_sum', 'stent_Stent_CONOR_sum', 'stent_Stent_COROFLEX BLUE_sum', 'stent_Stent_CYPHER_sum', 'stent_Stent_DIRECT STENT_sum', 'stent_Stent_DRIVER_sum', 'stent_Stent_ELIXIR_sum', 'stent_Stent_ENDEAVOR_sum', 'stent_Stent_ENDEAVOR RESOLUTE_sum', 'stent_Stent_EXPRESS_sum', 'stent_Stent_GENIUS_sum', 'stent_Stent_INSPIRON_sum', 'stent_Stent_INTEGRITY_sum', 'stent_Stent_KANAME_sum', 'stent_Stent_LEKTON_sum', 'stent_Stent_LEKTON MOTION_sum', 'stent_Stent_LEVENTON_sum', 'stent_Stent_LIBERTÉ_sum', 'stent_Stent_MATRIX_sum', 'stent_Stent_MGUARD_sum', 'stent_Stent_MICRO DRIVER_sum', 'stent_Stent_MICROPORT_sum', 'stent_Stent_MINI DRIVER_sum', 'stent_Stent_MULTILINK_sum', 'stent_Stent_NILE CROCO_sum', 'stent_Stent_NOBORI_sum', 'stent_Stent_OMEGA_sum', 'stent_Stent_PRESILLION_sum', 'stent_Stent_PRO-KINETIC_sum', 'stent_Stent_PROMUS_sum', 'stent_Stent_PROMUS ELEMENT_sum', 'stent_Stent_R-STENT_sum', 'stent_Stent_REBEL_sum', 'stent_Stent_RESOLUTE_sum', 'stent_Stent_RESOLUTE INTEGRITY_sum', 'stent_Stent_SINERGY_sum', 'stent_Stent_SIRIUS_sum', 'stent_Stent_SONIC_sum', 'stent_Stent_SUPRALIMUS_sum', 'stent_Stent_TAXUS_sum', 'stent_Stent_TENSUN_sum', 'stent_Stent_ULTIMASTER_sum', 'stent_Stent_ULTRA_sum', 'stent_Stent_V-FLEX_sum', 'stent_Stent_VISION_sum', 'stent_Stent_WIKTOR_sum', 'stent_Stent_XIENCE PRIME_sum', 'stent_Stent_XIENCE V_sum', 'stent_Stent_XIENCE XPEDITION_sum', 'stent_Stent_XT BARD_sum', 'stent_Stent_ZETA_sum', 'stent_Estratégia_Pré e Pós dilatação_sum', 'stent_Estratégia_Pré-dilatação_sum', 'stent_Estratégia_Pós-dilatação_sum', 'stent_Estratégia_Stent Direto_sum', 'stent_Resultado Angiográfico - Stent_I1 - Não ultrapassou a lesão_sum', 'stent_Resultado Angiográfico - Stent_I2 - Ultrapassou e não dilatou_sum', 'stent_Resultado Angiográfico - Stent_I3 - Oclusão Aguda_sum', 'stent_Resultado Angiográfico - Stent_I4 - Dissecção_sum', 'stent_Resultado Angiográfico - Stent_S - Sucesso_sum', 'stent_Tipo - Dissecção - Stent_A_sum', 'stent_Tipo - Dissecção - Stent_B_sum', 'stent_Tipo - Dissecção - Stent_C_sum', 'stent_Tipo - Dissecção - Stent_D_sum', 'stent_Tipo - Dissecção - Stent_E_sum', 'stent_Tipo - Dissecção - Stent_F_sum', 'stent_Localização da Dissecção_Pré Stent_sum', 'stent_Localização da Dissecção_Pré e Pós Stent_sum', 'stent_Localização da Dissecção_Pós Stent_sum', 'stent_Classificação da Lesão (ACC/AHA) - Stent_A_sum', 'stent_Classificação da Lesão (ACC/AHA) - Stent_B1_sum', 'stent_Classificação da Lesão (ACC/AHA) - Stent_B2_sum', 'stent_Classificação da Lesão (ACC/AHA) - Stent_C_sum', 'stent_Kissing wire - Stent_Não_sum', 'stent_Kissing wire - Stent_Sim_sum', 'stent_Kissing balloon - Stent_Não_sum', 'stent_Kissing balloon - Stent_Sim_sum', 'stent_Sobreposição_Não_sum', 'stent_Sobreposição_Sim_sum', 'stent_Distúrbio de Fluxo - Stent_Não_sum', 'stent_Distúrbio de Fluxo - Stent_Sim_sum', 'stent_Tipo do Distúrbio de Fluxo - Stent_No-reflow_sum', 'stent_Tipo do Distúrbio de Fluxo - Stent_Slow flow_sum', 'stent_Tipo No-Reflow_Inalterado após as medicações descritas_sum', 'stent_Tipo No-Reflow_Melhora completa_sum', 'stent_Tipo No-Reflow_Melhora parcial_sum', 'stent_Técnica de bifurcação_Crushing_sum', 'stent_Técnica de bifurcação_Cullote_sum', 'stent_Técnica de bifurcação_Mini Crushing_sum', 'stent_Técnica de bifurcação_SKS_sum', 'stent_Técnica de bifurcação_T Provisional_sum', 'stent_Técnica de bifurcação_T Stent_sum', 'stent_Técnica de bifurcação_V Stent_sum', 'stent_Stent Dedicado_Não_sum', 'stent_Stent Dedicado_Sim_sum', 'stent_Adenosina - Stent_Não_sum', 'stent_Adenosina - Stent_Sim_sum', 'stent_Papaverina - Stent_Não_sum', 'stent_Papaverina - Stent_Sim_sum', 'stent_Nitroglicerina - Stent_Não_sum', 'stent_Nitroglicerina - Stent_Sim_sum', 'stent_Monocordil - Stent_Não_sum', 'stent_Monocordil - Stent_Sim_sum', 'stent_Nitroprussiato - Stent_Não_sum', 'stent_Adrenalina - Stent_Não_sum', 'stent_Adrenalina - Stent_Sim_sum', 'vaso_Anatomia - Intervenção_Ateromatose moderada_sum', 'vaso_Anatomia - Intervenção_Ateromatose severa_sum', 'vaso_Anatomia - Intervenção_Com irregularidades parietais_sum', 'vaso_Anatomia - Intervenção_Com lesão_sum', 'vaso_Vaso coronário - Intervenção_CD_sum', 'vaso_Vaso coronário - Intervenção_CX_sum', 'vaso_Vaso coronário - Intervenção_DA_sum', 'vaso_Vaso coronário - Intervenção_DPD_sum', 'vaso_Vaso coronário - Intervenção_DPE_sum', 
intrastent - Intervenção_Proliferativa_sum', 'vaso_Tipo de Lesão - Focal - Intervenção_Borda IB_sum', 'vaso_Tipo de Lesão - Focal - Intervenção_Focal corpo stent IC_sum', 'vaso_Tipo de Lesão - Focal - Intervenção_Multifocal ID_sum', 'vaso_Tipo de Lesão - Focal - Intervenção_gap IA_sum', 'vaso_Tipo de Lesão - Difusa - Intervenção_Intra-stent II_sum', 'vaso_Tipo de Lesão - Difusa - Intervenção_Oclusão total_sum', 'vaso_Tipo de Lesão - Difusa - Intervenção_Proliferativca III_sum', 'vaso_Tipo de Lesão - Pós balão - Intervenção_Tardia_sum', 'vaso_Calcificação - Intervenção_Acentuada_sum', 'vaso_Calcificação - Intervenção_Ausente_sum', 'vaso_Calcificação - Intervenção_Discreta_sum', 'vaso_Calcificação - Intervenção_Moderada_sum', 'vaso_Tortuosidade - Intervenção_Acentuada_sum', 'vaso_Tortuosidade - Intervenção_Leve_sum', 'vaso_Tortuosidade - Intervenção_Moderada_sum', 'vaso_Angulação - Intervenção_gt45_sum', 'vaso_Angulação - Intervenção_gt90_sum', 'vaso_Angulação - Intervenção_Acentuada_sum', 'vaso_Angulação - Intervenção_Leve_sum', 'vaso_Angulação - Intervenção_Moderada_sum', 'vaso_Grau de Importância - Intervenção_Discreta_sum', 'vaso_Grau de Importância - Intervenção_Grande_sum', 'vaso_Grau de Importância - Intervenção_Moderada_sum', 'vaso_Maior que 20mm - Intervenção_Não_sum', 'vaso_Maior que 20mm - Intervenção_Sim_sum', 'vaso_Trombo - Intervenção_Não_sum', 'vaso_Trombo - Intervenção_Sim_sum', 'vaso_Placa Rota - Intervenção_Não_sum', 'vaso_Placa Rota - Intervenção_Sim_sum', 'vaso_Placa Ulcerada - Intervenção_Não_sum', 'vaso_Placa Ulcerada - Intervenção_Sim_sum', 'vaso_Ectasia - Intervenção_Não_sum', 'vaso_Ectasia - Intervenção_Sim_sum', 'vaso_Aneurisma - Intervenção_Não_sum', 'vaso_Aneurisma - Intervenção_Sim_sum', 'vaso_Bifurcação - Intervenção_001_sum', 'vaso_Bifurcação - Intervenção_010_sum', 'vaso_Bifurcação - Intervenção_011_sum', 'vaso_Bifurcação - Intervenção_100_sum', 'vaso_Bifurcação - Intervenção_101_sum', 'vaso_Bifurcação - Intervenção_110_sum', 'vaso_Bifurcação - Intervenção_111_sum']].astype('object', copy=False)

# %%
dataSet.dtypes
# Out:
# Unnamed: 0                                int64
# evolucao_Nº. Paciente                     int64
# evolucao_Nº da Intervenção                int64
# evolucao_Problema Clínico                 int64
# evolucao_Infarto após Intervenção         int64
#                                           ...
# vaso_Bifurcação - Intervenção_011_sum    object
# vaso_Bifurcação - Intervenção_100_sum    object
# vaso_Bifurcação - Intervenção_101_sum    object
# vaso_Bifurcação - Intervenção_110_sum    object
# vaso_Bifurcação - Intervenção_111_sum    object
# Length: 666, dtype: object

# %%
 #@title Função para análise descritiva 
 from statsmodels.distributions.empirical_distribution import ECDF

 class ExploratoryAnalyser:
  
     def __init__(self, dataSet, targetVariable = 'target'):
         """ Initiator for ExploratoryAnalyser class
         """
         self.targetVariable = targetVariable
         self.dataSet = dataSet
                
         try:
             dataSet[targetVariable]
         except:
             raise ValueError('Target variable "%s" not found on data set.' % targetVariable)
         self.targetDomain = self.getTargetDomain()
 
         self.dataSummary = self.summary()
           

     def getTargetDomain(self):
         """Compute unique values for target variable. Currently it must be a binary variable."""
         targetVariable = self.targetVariable
         uniqueValue = self.dataSet[targetVariable].unique()
         if uniqueValue.shape[0] != 2: 
             raise ValueError('Target variable "%s" is not binary.' % targetVariable)
         else:
             return(uniqueValue)
   
     def checkVariableType(self,explanatoryVariable):
         """ Return variable type mapped according to the type of plot to be done. Currently:
         continous = ['float64','int64']
         categorical = ['object']
         If variable type is not yet mapped a error will be raised.
         """
         continous = ['float64','int64']
         categorical = ['object']
         if (self.dataSet[explanatoryVariable].dtype in continous): 
             return "continous"
         elif (self.dataSet[explanatoryVariable].dtype in categorical): 
             return "categorical"
         else:
             raise ValueError("Not ready to deal with '%s' data type." % self.dataSet[explanatoryVariable].dtype)

   
     def plotContinousVariable(self,dataSet,explanatoryVariable,targetVariable,domain,fontSize):
         # Density plots to compare conditional distribution
         plt.style.use('fivethirtyeight')
         fig, ax = plt.subplots(figsize=(20,8), nrows=1, ncols=2)
         for i in range(domain.shape[0]):
             subset = dataSet[dataSet[targetVariable] == domain[i]]
             try:
                 sns.distplot(subset[explanatoryVariable],ax=ax[0],hist=False,kde=True,
                          kde_kws={'shade': True, 'linewidth': 2},label=domain[i])
             except: 
                 sns.distplot(subset[explanatoryVariable],ax=ax[0],hist=False,kde=True,
                          kde_kws={'shade': True, 'linewidth': 2,'bw': 0.1},label=domain[i])
         ax[0].set_title('Histogram - n = {}'.format(len(self.dataSet)))

         # Empirical CDF - KS
         for i in range(domain.shape[0]):
             subset = dataSet[dataSet[targetVariable] == domain[i]]
             cdf = ECDF(subset[explanatoryVariable])
             ax[1].plot(cdf.x, cdf.y, label=domain[i])
         ax[1].set_xlabel(explanatoryVariable)
         ax[1].legend(loc='upper left')
         ks = stats.ks_2samp(dataSet.loc[dataSet[targetVariable] == domain[0], explanatoryVariable],
                       dataSet.loc[dataSet[targetVariable] == domain[1], explanatoryVariable])[0]
         ax[1].set_title('CDF - KS = {}'.format(round(ks,2)))                
         plt.show()
       
     def plotCategoricalVariable(self,dataSet,explanatoryVariable,targetVariable,domain,fontSize):
         # Bar chart showing distribution of target variables across categories
         plt.style.use('fivethirtyeight')
         fig, ax = plt.subplots(figsize=(20,8), nrows=1, ncols=2)

         dataSet.groupby(explanatoryVariable)[targetVariable].\
             value_counts(normalize = True , dropna = False).unstack(1).reset_index().\
             plot(x = explanatoryVariable, y = domain,kind = 'bar',ax = ax[0])
         ax[0].set_title(explanatoryVariable,fontsize = fontSize*2)
         plt.setp(ax[0].get_xticklabels(), rotation=70, horizontalalignment='right')
         ax[0].legend(bbox_to_anchor=(1.05, 1), loc='upper right', borderaxespad=0.)
         ax[0].set_xlabel(explanatoryVariable)
         ax[0].set_ylabel('Percentage')

         for i in ax[0].patches:
              ax[0].text(i.get_x(), i.get_height()+0.01, \
              str(round((i.get_height()*100), 2)), fontsize=fontSize, color='black')
       
            
     def plotDistributions(self,explanatoryVariable,maxCategories = 10):
         """ Main function to plot analyses
          Basically just determine whether to call categorical or continoues plots 
          explanatoryVariable = String, variable that you want to analyse
          maxCategories = Int, default 10, variable that you use to limit categories on plot """
         fontSize = 10
         targetVariable = self.targetVariable
         targetDomain = self.targetDomain
         
         try:
             self.dataSet[explanatoryVariable]
         except:
             raise ValueError('Explanatory Variable "%s" not found on data set.' % explanatoryVariable)

         variableType = self.checkVariableType(explanatoryVariable)
   
         print("Chart for '%s':" % explanatoryVariable)

         if ( variableType == "continous"):
             self.plotContinousVariable(self.dataSet,explanatoryVariable,targetVariable,targetDomain,fontSize)

         elif (variableType == "categorical"):
             if self.dataSummary.at[explanatoryVariable,'Unique domain'] <= maxCategories:
                 self.plotCategoricalVariable(self.dataSet,explanatoryVariable,targetVariable,targetDomain,fontSize)
             else:
                 print("Too many categories!")

         else: 
             self.checkVariableType(explanatoryVariable)
       
     def checkMissing(self):
         return self.dataSet.isna().mean().sort_values(ascending=False)
   
     def checkDomain(self):
         uniqueCountSeries = pd.Series([])
         for i in self.dataSet.columns:
             element = pd.Series(self.dataSet[i].nunique(),index = [i])
             uniqueCountSeries = uniqueCountSeries.append(element)

         return uniqueCountSeries.sort_values(ascending=False)
   
     def checkMode(self):
         modeSeries  = pd.Series([])
         modePercentageSeries = pd.Series([])
         for i in self.dataSet.columns:
             mode = self.dataSet[i].value_counts(normalize=True).sort_values(ascending=False)
             modeSeries = modeSeries.append(pd.Series(mode.index[0],index = [i]) )
             modePercentageSeries = modePercentageSeries.append(pd.Series(mode.iloc[0],index = [i]))
         return modeSeries, modePercentageSeries

   
     def summary(self):
         missing = pd.DataFrame(self.checkMissing(),columns=["Missing"])
         domain = pd.DataFrame(self.checkDomain(),columns=["Unique domain"])
         dataTypes = pd.DataFrame(self.dataSet.dtypes,columns=["Type"])
         modeSeries, modePercentageSeries = self.checkMode()
         modeSeries = pd.DataFrame(modeSeries,columns = ["Mode"])
         modePercentageSeries = pd.DataFrame(modePercentageSeries,columns = ["Mode percentage"])
         return missing.join(domain).join(dataTypes).join(modeSeries).join(modePercentageSeries)

# %%
#@title Plot das análises
dataSet['target']=dataSet['evolucao_Problema Clínico']
obj = ExploratoryAnalyser(dataSet) 
for i in dataSet.columns:
    obj.plotDistributions(i)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# A seguir são descritos alguns dos casos observados nas análise que nos ajudam a dar insights para disernir os casos de sucesso e fracasso clínico.
#
# # Paciente
# * 'paciente_Idade no procedimento' - acima de 90+ anos parece ser exclusivo do fracaso
# * 'paciente_Peso (Kg)' - acima de 140 parece ser exclusivo fracaso
# * 'paciente_Índice de Massa Corporal' - acima de 40 parece ser exclusivo fracaso
# * 'paciente_Pressão Arterial_min':<80 e >210 parece ser exclusivo do fracasso
# * 'paciente_Pressão Arterial_max': <130 e >210 parece ser exclusivo fracaso
# * 'paciente_Raça_Mestiço' - mestiços parecem ter uma taxa maior de fracasso (checar valor absoluto)
# * 'paciente_Tratamento Diabetes_Dieta' - =1 parecem ter uma taxa maior de fracasso (checar valor absoluto)
# * 'paciente_Tratamento_Sem Tratamento' - =0 parecem ter uma taxa maior de fracasso (checar valor absoluto)
# * 'paciente_Tratamento Dislipidemia_Fibrato' - =0 parecem ter uma taxa maior de fracasso (checar valor absoluto)
# * 'paciente_IRC_Sim' - =1 parecem ter uma taxa maior de fracasso (checar valor absoluto)
# * 'paciente_Tipo IRC_Dialítica' - =1 parecem ter uma taxa maior de fracasso (checar valor absoluto)
# * 'paciente_AVC prévio_Sim' - =1 parecem ter uma taxa maior de fracasso (checar valor absoluto)
# * 'paciente_Tipo Doença Vascular Periférica_Operada / Intervenção prévia' - =1 parecem ter uma taxa maior de fracasso (checar valor absoluto)
# * 'paciente_DPOC_Sim'- =1 parecem ter uma taxa maior de fracasso (checar valor absoluto)
#
# # Procedimento
# * 'procedimento_Porta/Interv.(hrs) - Urgência_max': >100 parece ser exclusivo de sucesso
# * 'procedimento_Porta/Interv.(hrs) - Urgência_min' : >100 parece ser exclusivo de sucesso
# * 'procedimento_Duração Interv. (min)_max': >200 parece ser exclusivo do fracasso
# * 'procedimento_Anestesia - Intervenção_Geral Inalatória_sum': =1 parecem ter uma taxa maior de fracasso (checar valor absoluto)
# * 'procedimento_Droga - Intervenção_Fentanil_sum':- =1 parecem ter uma taxa maior de fracasso (checar valor absoluto)
# * 'procedimento_Droga - Intervenção_Thionembutal_sum': =1 parecem ter uma taxa maior de fracasso (checar valor absoluto)
# * procedimento_Introdutor - Intervenção_7F_sum': =1 parecem ter uma taxa maior de fracasso (checar valor absoluto)
# * 'procedimento_Introdutor - Intervenção_8F_sum': =1 parecem ter uma taxa maior de fracasso (checar valor absoluto)
# * 'procedimento_Via de acesso - Intervenção_Braquial Dissecção_sum'= 1 parecem ter uma taxa maior de fracasso (checar valor absoluto)
# * 'procedimento_Lado Via de Acesso - Intervenção_Direito e Esquerdo_sum' =1 parecem ter uma taxa maior de fracasso (checar valor absoluto) - bem diferente
# *'procedimento_Nome Comercial - Intervenção_HENETIX 350_sum' =1 parecem ter uma taxa maior de fracasso (checar valor absoluto) - bem diferente
# * 'procedimento_Nome Comercial - Intervenção_OPTIRAY 240_sum':= 1 parecem ter uma taxa maior de fracasso (checar valor absoluto)
# * 'procedimento_Trombolítico Prévio - Resgate_rPA_sum': =1 parecem ter uma taxa maior de fracasso (checar valor absoluto)
# * parecem ter uma taxa maior de fracasso (checar valor absoluto)
# * parecem ter uma taxa maior de fracasso (checar valor absoluto)
# * parecem ter uma taxa maior de fracasso (checar valor absoluto)
#
#
# # Balão
# * 'balao_Grau de estenose pós_mean':
# * 'balao_Grau de estenose pós_max':
# * 'balao_Blush Miocárdico_mean':
# * 'balao_Blush Miocárdico_max':
# * stent_Grau de estenose pós_mean
#
#
# # Stent
# * 'stent_Pressão Final de Liberação (ATM)_mean':
# * 'stent_Grau de estenose pós_mean'
# * 'stent_Stent_SINERGY_sum'
# * 'stent_Stent_VISION_sum'
# * 'stent_Stent_XIENCE XPEDITION_sum'
# * *'stent_Estratégia_Pré e Pós dilatação_sum'
# * *'stent_Resultado Angiográfico - Stent_I1 - Não ultrapassou a lesão_sum'
# * *'stent_Resultado Angiográfico - Stent_I2 - Ultrapassou e não dilatou_sum'
# * *'stent_Resultado Angiográfico - Stent_I3 - Oclusão Aguda_sum'
#
#
# # Vaso
# * 'vaso_Tipo de Lesão - Intervenção_De Novo_sum':
# * 'vaso_Tipo de Lesão - Intervenção_Oclusão total crônica_sum':
# * 'vaso_Calcificação - Intervenção_Acentuada_sum':

# %% [markdown]
# Vamos gerar boxplots para as variáveis contínuas elencadas acima

# %%
sns.set_style("whitegrid")

# %%
 sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'paciente_Idade no procedimento' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'paciente_Peso (Kg)' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'paciente_Pressão Arterial_min' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'paciente_Pressão Arterial_max' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'procedimento_Porta/Interv.(hrs) - Urgência_max' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'procedimento_Porta/Interv.(hrs) - Urgência_min' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'procedimento_Duração Interv. (min)_max' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'balao_Grau de estenose pós_mean' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'balao_Grau de estenose pós_max' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'balao_Blush Miocárdico_mean' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'balao_Blush Miocárdico_max' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'stent_Grau de estenose pós_mean' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'stent_Pressão Final de Liberação (ATM)_mean' , data = dataSet)

# %% [markdown]
# Podemos observar que as informações de balão foram as que deram mais diferença entre os grupos de fracasso e sucesso clínico

# %% [markdown]
# Agora vamos observar os boxplots para as variáveis contínuas elencadas pelos modelos como mais importantes mas não apareceram na análise acima:
#
# * 'paciente_Altura (metros)'
# * 'paciente_Índice de Massa Corporal'
# * 'procedimento_Qtde (ml)_max'
# * 'procedimento_Duração Interv. (min)_sum'
# * 'procedimento_Tempo origem/balão (minutos) - Primária_max'
# * 'procedimento_Tempo origem/balão (minutos) - Primária_mean'
# * 'balao_Grau de estenose pós_max'
# * 'balao_Timi pós_max'
# * 'stent_Diâmetro Dispositivo - Stent_count'
# * 'stent_Comprimento Dispositivo - Stent_mean'
# * 'stent_Timi pós_mean'
# * 'stent_Timi pós_max'

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'paciente_Altura (metros)' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'paciente_Índice de Massa Corporal' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'procedimento_Qtde (ml)_max' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'procedimento_Duração Interv. (min)_sum' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'procedimento_Tempo origem/balão (minutos) - Primária_max' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'procedimento_Tempo origem/balão (minutos) - Primária_mean' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'balao_Grau de estenose pós_max' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'balao_Timi pós_max' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'stent_Diâmetro Dispositivo - Stent_count' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'stent_Comprimento Dispositivo - Stent_mean' , data = dataSet)

# %%
sns.boxplot(x = 'evolucao_Problema Clínico' , y = 'stent_Timi pós_max' , data = dataSet)

# %%
df_interesse = dataSet[['paciente_Altura (metros)','paciente_Índice de Massa Corporal','procedimento_Qtde (ml)_max','procedimento_Duração Interv. (min)_sum'
,'procedimento_Tempo origem/balão (minutos) - Primária_max','procedimento_Tempo origem/balão (minutos) - Primária_mean'
,'balao_Grau de estenose pós_max','balao_Timi pós_max','stent_Diâmetro Dispositivo - Stent_count'
,'stent_Comprimento Dispositivo - Stent_mean','stent_Timi pós_mean','stent_Timi pós_max']]

# %%
#@title Matriz com Correlações, Histogramas e Scatter plots { vertical-output: false, display-mode: "both" }
def corrdot(*args, **kwargs):
    corr_r = args[0].corr(args[1], 'pearson')
    corr_text = f"{corr_r:2.2f}".replace("0.", ".")
    ax = plt.gca()
    ax.set_axis_off()
    marker_size = abs(corr_r) * 10000
    ax.scatter([.5], [.5], marker_size, [corr_r], alpha=0.6, cmap="coolwarm",
               vmin=-1, vmax=1, transform=ax.transAxes)
    font_size = abs(corr_r) * 40 + 5
    ax.annotate(corr_text, [.5, .5,],  xycoords="axes fraction",
                ha='center', va='center', fontsize=font_size)
    

sns.set(style='white', font_scale=1.6)
g = sns.PairGrid(df_interesse, aspect=1.4, diag_sharey=False)
g.map_lower(sns.regplot, lowess=True, ci=False, line_kws={'color': 'black'})
g.map_diag(sns.distplot, kde_kws={'color': 'black'})
g.map_upper(corrdot)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/axisgrid.py:1342: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   fig.tight_layout(pad=layout_pad)
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/smoothers_lowess.py:165: RuntimeWarning: invalid value encountered in true_divide
#   res = _lowess(y, x, frac=frac, it=it, delta=delta)
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/smoothers_lowess.py:165: RuntimeWarning: invalid value encountered in greater_equal
#   res = _lowess(y, x, frac=frac, it=it, delta=delta)
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/smoothers_lowess.py:165: RuntimeWarning: invalid value encountered in true_divide
#   res = _lowess(y, x, frac=frac, it=it, delta=delta)
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/smoothers_lowess.py:165: RuntimeWarning: invalid value encountered in greater_equal
# ...
